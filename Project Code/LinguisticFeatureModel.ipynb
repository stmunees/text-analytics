# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split
from sklearn.ensemble  import RandomForestClassifier
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

sns.set_style('white')
sns.set_context("poster")

# %%
data = pd.read_csv('dataset/data_with_tags.csv')

# %%
data
# Out:
#                                                    Review  Polarity  Useful  \
# 0       tai stylist carol hair make wedding absolutely...         1       3
# 1       highly recommend sara looking great talented h...         1       5
# 2       not know going costco could become hobby come ...         1       3
# 3       bit pricey consistently delicious service alwa...         1       0
# 4       ashley gave tour apartment nice helpful apartm...         1       0
# ...                                                   ...       ...     ...
# 526116  top chef master expect much horrible experienc...        -1       3
# 526117  die hard foodie spends way much income eating ...         1       0
# 526118  dr vaughn miracle doctor came see doctor vaugh...         1       2
# 526119  went place yrs ago not crazy not back tonight ...        -1       1
# 526120  drive young black girl got upset spoke loudly ...        -1       0
#
#         ReviewLength  Nouns  Adjectives  Verbs
# 0                277   22.0         8.0    6.0
# 1               1380   79.0        38.0   55.0
# 2                469   26.0        14.0   18.0
# 3                106    4.0         6.0    1.0
# 4                 70    4.0         5.0    1.0
# ...              ...    ...         ...    ...
# 526116           877   53.0        28.0   33.0
# 526117           340   26.0         9.0    6.0
# 526118           611   37.0        19.0   17.0
# 526119           225   11.0         8.0    8.0
# 526120           277   16.0         6.0   14.0
#
# [526121 rows x 7 columns]

# %%
data.describe()
# Out:
#             Polarity         Useful   ReviewLength          Nouns  \
# count  526121.000000  526121.000000  526121.000000  526121.000000
# mean       -0.000032       1.589389     400.709890      25.092732
# std         1.000001       5.513974     373.382025      23.555645
# min        -1.000000       0.000000       2.000000       0.000000
# 25%        -1.000000       0.000000     160.000000      10.000000
# 50%        -1.000000       1.000000     285.000000      18.000000
# 75%         1.000000       2.000000     507.000000      32.000000
# max         1.000000    1608.000000    4745.000000     505.000000
#
#           Adjectives          Verbs
# count  526121.000000  526121.000000
# mean       11.911980      13.500619
# std        10.886125      14.019530
# min         0.000000       0.000000
# 25%         5.000000       5.000000
# 50%         9.000000       9.000000
# 75%        15.000000      17.000000
# max       189.000000     218.000000

# %%
## Useful got some aweful outliers

data['Useful'].unique()
# Out:
# array([   3,    5,    0,    1,    4,    2,    9,    7,   10,    8,   46,
#          24,    6,   17,   39,   12,   23,   30,   11,   16,   14,   76,
#          21,   13,   18,   22,   44,   29,   15,   35,   20,   75,   28,
#          27,   19,   53,   26,   25,   33,   40,   32,   31,   57,  121,
#          64,   41,   36,   51,   38,   37,   42,   34,   45,   56,   84,
#          48,   61,   47,  128,   62,   68,   80,   43,   55,   77,   71,
#          74,   66,   69,  615,   63,   92,  176, 1608,  286,   72,   52,
#         134,   50,  108,   49,   86,   96,  397,   54,   85,   59,  178,
#         500,   67,  110,   87,  463,   91, 1112,  150,  117,  647,   70,
#         145,   58,   60,   94,   73,  113,  412,  777,   98,  130,  120,
#         180,  245,   65,  190,  203,  181,  114,  782,  168,   89,  415,
#         445,   99,  131,  132,  139,  255,  107,  165,  101,   82,  122,
#         200,   79,  279,  643,   88,  127,  600,  358,   93,  161,  248,
#          97,  118,  693,  954], dtype=int64)

# %%
#Removing Useful outliers


top_99 = data["Useful"].quantile(0.99)
data = data[data["Useful"] < top_99]

# %%
data.describe()
# Out:
#             Polarity         Useful   ReviewLength          Nouns  \
# count  520789.000000  520789.000000  520789.000000  520789.000000
# mean        0.003823       1.332231     395.492086      24.772153
# std         0.999994       2.138093     365.631457      23.093926
# min        -1.000000       0.000000       2.000000       0.000000
# 25%        -1.000000       0.000000     159.000000      10.000000
# 50%         1.000000       1.000000     282.000000      18.000000
# 75%         1.000000       2.000000     501.000000      31.000000
# max         1.000000      14.000000    4745.000000     505.000000
#
#           Adjectives          Verbs
# count  520789.000000  520789.000000
# mean       11.781812      13.306813
# std        10.700925      13.729505
# min         0.000000       0.000000
# 25%         5.000000       5.000000
# 50%         9.000000       9.000000
# 75%        15.000000      17.000000
# max       189.000000     218.000000

# %%
g = sns.PairGrid(data)
g.map(plt.scatter)

# %%
sns.relplot(x="Useful", y="Nouns", data=data, hue="Polarity", style="Polarity");
sns.relplot(x="Useful", y="Adjectives", data=data, hue="Polarity", style="Polarity");
sns.relplot(x="Useful", y="Verbs", data=data, hue="Polarity", style="Polarity");

# %%
data['Useful'].unique()
# Out:
# array([ 3,  5,  0,  1,  4,  2,  9,  7, 10,  8,  6, 12, 11, 14, 13],
#       dtype=int64)

# %%
# Dividing the usefulness:
'''
 * < 2 Low
 * >= 2 High
''' 

def applyUsefulness(useful):
    if useful < 2:
        return 0 #return 'low'
    
    return 1 #return 'high'

# %%
UsefulnessColumn = data['Useful']
Usefulness = UsefulnessColumn.map(applyUsefulness)
data['UsefulnessPolarity'] = Usefulness
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['UsefulnessPolarity'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.relplot(x="UsefulnessPolarity", y="Nouns", data=data, hue="Polarity", style="Polarity");
sns.relplot(x="UsefulnessPolarity", y="Adjectives", data=data, hue="Polarity", style="Polarity");
sns.relplot(x="UsefulnessPolarity", y="Verbs", data=data, hue="Polarity", style="Polarity");

# %% [markdown]
# ### Models with only linguistic features

# %%
data.head()
# Out:
#                                               Review  Polarity  Useful  \
# 0  tai stylist carol hair make wedding absolutely...         1       3
# 1  highly recommend sara looking great talented h...         1       5
# 2  not know going costco could become hobby come ...         1       3
# 3  bit pricey consistently delicious service alwa...         1       0
# 4  ashley gave tour apartment nice helpful apartm...         1       0
#
#    ReviewLength  Nouns  Adjectives  Verbs  UsefulnessPolarity
# 0           277   22.0         8.0    6.0                   1
# 1          1380   79.0        38.0   55.0                   1
# 2           469   26.0        14.0   18.0                   1
# 3           106    4.0         6.0    1.0                   0
# 4            70    4.0         5.0    1.0                   0

# %%
data.corr()
# Out:
#                     Polarity    Useful  ReviewLength     Nouns  Adjectives  \
# Polarity            1.000000 -0.139732     -0.163123 -0.142449   -0.059749
# Useful             -0.139732  1.000000      0.314276  0.300790    0.279250
# ReviewLength       -0.163123  0.314276      1.000000  0.971990    0.936687
# Nouns              -0.142449  0.300790      0.971990  1.000000    0.910543
# Adjectives         -0.059749  0.279250      0.936687  0.910543    1.000000
# Verbs              -0.234519  0.313030      0.950818  0.891535    0.835236
# UsefulnessPolarity -0.134112  0.758963      0.273420  0.261051    0.246939
#
#                        Verbs  UsefulnessPolarity
# Polarity           -0.234519           -0.134112
# Useful              0.313030            0.758963
# ReviewLength        0.950818            0.273420
# Nouns               0.891535            0.261051
# Adjectives          0.835236            0.246939
# Verbs               1.000000            0.270484
# UsefulnessPolarity  0.270484            1.000000

# %%
dataToConsider = data[['Polarity', 'ReviewLength', 'Nouns', 'Adjectives', 'Verbs', 'UsefulnessPolarity']]

# %%
X = dataToConsider.drop('UsefulnessPolarity', axis = 1)
y = dataToConsider['UsefulnessPolarity']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)

# %% [markdown]
# ### DecisionTreeClassifier

# %%
dtree_model = DecisionTreeClassifier(max_depth = 5).fit(X_train, y_train) 
dtree_predictions = dtree_model.predict(X_test) 
print("Accuracy:",metrics.accuracy_score(y_test, dtree_predictions))
# Out:
# Accuracy: 0.7244811748260342

# %%
conf_mat = confusion_matrix(y_test, dtree_predictions)
class_label = [ "high","low"]
df = pd.DataFrame(conf_mat, index = class_label, columns = class_label)
sns.heatmap(df, annot = True,fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

predi=dtree_model.predict_proba(X_test)[:,1]
fpr1, tpr1, thresholds1 = metrics.roc_curve(y_test, predi)

pred=dtree_model.predict_proba(X_train)[:,1]
fpr2,tpr2,thresholds2=metrics.roc_curve(y_train,pred)

fig = plt.figure()
ax = plt.subplot(111)
ax.plot(fpr1, tpr1, label='Test ROC ,auc='+str(roc_auc_score(y_test,predi)))
ax.plot(fpr2, tpr2, label='Train ROC ,auc='+str(roc_auc_score(y_train,pred)))
plt.title('ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
ax.legend()
plt.show()

# %% [markdown]
# ### Random Forest Classifier

# %%
classifier = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', random_state = 42)
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6727676308391835

# %%
conf_mat = confusion_matrix(y_test, y_pred)
class_label = ["high", "low"]
df = pd.DataFrame(conf_mat, index = class_label, columns = class_label)
sns.heatmap(df, annot = True,fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
predi=classifier.predict_proba(X_test)[:,1]
fpr1, tpr1, thresholds1 = metrics.roc_curve(y_test, predi)

pred=classifier.predict_proba(X_train)[:,1]
fpr2,tpr2,thresholds2=metrics.roc_curve(y_train,pred)

fig = plt.figure()
ax = plt.subplot(111)
ax.plot(fpr1, tpr1, label='Test ROC ,auc='+str(roc_auc_score(y_test,predi)))
ax.plot(fpr2, tpr2, label='Train ROC ,auc='+str(roc_auc_score(y_train,pred)))
plt.title('ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
ax.legend()
plt.show()

# %% [markdown]
# ### Naive Bayes classifier

# %%
gnb = GaussianNB().fit(X_train, y_train) 
gnb_predictions = gnb.predict(X_test) 
  
# accuracy on X_test 
accuracy = gnb.score(X_test, y_test) 
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7205717445736494

# %%
conf_mat = confusion_matrix(y_test, gnb_predictions)
class_label = ["high", "high"]
df = pd.DataFrame(conf_mat, index = class_label, columns = class_label)
sns.heatmap(df, annot = True,fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
predi=gnb.predict_proba(X_test)[:,1]
fpr1, tpr1, thresholds1 = metrics.roc_curve(y_test, predi)

pred=gnb.predict_proba(X_train)[:,1]
fpr2,tpr2,thresholds2=metrics.roc_curve(y_train,pred)

fig = plt.figure()
ax = plt.subplot(111)
ax.plot(fpr1, tpr1, label='Test ROC ,auc='+str(roc_auc_score(y_test,predi)))
ax.plot(fpr2, tpr2, label='Train ROC ,auc='+str(roc_auc_score(y_train,pred)))
plt.title('ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
ax.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### K Neighbors Classifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5).fit(X_train, y_train) 
y_pred = knn.predict(X_test)
# accuracy on X_test 
accuracy = knn.score(X_test, y_test) 
print(accuracy)
# Out:
# 0.6878600285718675

# %%
conf_mat = confusion_matrix(y_test, y_pred)
class_label = ["high", "low"]
df = pd.DataFrame(conf_mat, index = class_label, columns = class_label)
sns.heatmap(df, annot = True,fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
predi=knn.predict_proba(X_test)[:,1]
fpr1, tpr1, thresholds1 = metrics.roc_curve(y_test, predi)

pred=knn.predict_proba(X_train)[:,1]
fpr2,tpr2,thresholds2=metrics.roc_curve(y_train,pred)

fig = plt.figure()
ax = plt.subplot(111)
ax.plot(fpr1, tpr1, label='Test ROC ,auc='+str(roc_auc_score(y_test,predi)))
ax.plot(fpr2, tpr2, label='Train ROC ,auc='+str(roc_auc_score(y_train,pred)))
plt.title('ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')
ax.legend()
plt.show()
