# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

path='drive/My Drive/Text Analytics/Dataset/pos_cleaned_25k_yelp.csv'
another_path='drive/My Drive/Text Analytics/Dataset/outputNEGSET1.csv'
pos_cleaned = pd.read_csv(path)
pos_lcs = pd.read_csv(another_path)

# %%
pos_lcs.head()
# Out:
#    Filename    W  S  VP   C   T  ...     T/S    CT/T    CP/T    CP/C    CN/T    CN/C
# 0         0  120  8  17  14   9  ...  1.1250  0.2222  0.3333  0.2143  1.2222  0.7857
# 1         1   76  5  12  10   7  ...  1.4000  0.2857  0.1429  0.1000  0.4286  0.3000
# 2         2  102  8  18  11  10  ...  1.2500  0.2000  0.4000  0.3636  0.9000  0.8182
# 3         3  252  8  38  26  13  ...  1.6250  0.3077  0.3077  0.1538  1.5385  0.7692
# 4         4   83  3  12  11   8  ...  2.6667  0.5000  0.0000  0.0000  1.0000  0.7273
#
# [5 rows x 24 columns]

# %%
pos_cleaned.head()
# Out:
#    stars        date                                               text  useful
# 0      5  2016-10-11  Nice Find!\n\nWe just happened on this restaur...       0
# 1      4  2015-01-13  So customer service might not be the greatest ...       2
# 2      4  2014-05-29  Never knew about this coffee shop until they o...       0
# 3      4  2014-11-13  Came here the other day to get a 60-minute det...       7
# 4      5  2016-11-10  This place is a bit of an institution and I us...       0

# %%
gg=pd.concat([pos_lcs,pos_cleaned['useful']],axis=1)
del gg['Filename']
gg.head()
# Out:
#      W  S  VP   C   T  DC  ...    CT/T    CP/T    CP/C    CN/T    CN/C  useful
# 0  120  8  17  14   9   3  ...  0.2222  0.3333  0.2143  1.2222  0.7857       0
# 1   76  5  12  10   7   2  ...  0.2857  0.1429  0.1000  0.4286  0.3000       2
# 2  102  8  18  11  10   3  ...  0.2000  0.4000  0.3636  0.9000  0.8182       0
# 3  252  8  38  26  13  10  ...  0.3077  0.3077  0.1538  1.5385  0.7692       7
# 4   83  3  12  11   8   3  ...  0.5000  0.0000  0.0000  1.0000  0.7273       0
#
# [5 rows x 24 columns]

# %%
temp = sns.PairGrid(gg)
temp.map(plt.scatter)

# %% [markdown]
# There is a normal distribution (kind of) between DC/C vs Useful graph and CT/T vs Useful Graph, meaning too low or too much of that affects people's want to vote the review as useful negatively.
